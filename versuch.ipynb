# %%
# %pylab
# %matplotlib inline
from matplotlib import pyplot as plt
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# image to grayscale

img = imread(r"data\Otsu_data\NIH3T3\img\dna-44.png")
imgc = img.copy()
imshow(imgc,'gray')

figure()

plt.hist(imgc.flatten())
# Out:
# (array([616806., 475731., 174730.,  59216.,  29201.,   9181.,   4539.,
#           2020.,   1205.,   3627.]),
#  array([0.06666667, 0.16      , 0.25333333, 0.34666666, 0.44      ,
#         0.53333336, 0.62666667, 0.72      , 0.81333333, 0.9066667 ,
#         1.        ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
#from 0-1 to 0-255

pixels = (img.flatten())

pixels255 = list()
for i in range(0,len(pixels)):
    pixels255.append(pixels[i]*255)
plt.hist(pixels255)
# Out:
# (array([616806., 475731., 174730.,  59216.,  29201.,   9181.,   4539.,
#           2020.,   1205.,   3627.]),
#  array([ 17.00000089,  40.8000008 ,  64.60000071,  88.40000062,
#         112.20000053, 136.00000044, 159.80000035, 183.60000027,
#         207.40000018, 231.20000009, 255.        ]),
#  <BarContainer object of 10 artists>)

# %%
from images_segmentation import otsu
from images_segmentation import initialNIH3T3


#kernel crash bei tif bilderfiles

# %%
# Bilder von N2DHGOWT1 laden
# zuerst ohne preprocessing +otsu+ Dice score
# mit preprocessing und unterschiedlichen Filtern (Gaus vs Median) erneut Dice score
# notieren was besser ist
#...
# wie kann man jetzt hier die ganzen bilder reinladen dachte das geht via unserem erstellten file im package....
# + Kernel crash schon wieder...
#ground_truth_NIH3T3 = [gt1, gt2, gt3, gt4, gt5, gt6, gt7, gt8, gt9, gt10, gt11, gt12, gt13, gt14, gt15, gt16, gt17 ,gt18]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Helen Jade\OneDrive\Desktop\2022-topic-01-team-04\versuch.ipynb Cell 6' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Helen%20Jade/OneDrive/Desktop/2022-topic-01-team-04/versuch.ipynb#ch0000005?line=0'>1</a> # Bilder von N2DHGOWT1 laden
#       <a href='vscode-notebook-cell:/c%3A/Users/Helen%20Jade/OneDrive/Desktop/2022-topic-01-team-04/versuch.ipynb#ch0000005?line=1'>2</a> # zuerst ohne preprocessing +otsu+ Dice score
#       <a href='vscode-notebook-cell:/c%3A/Users/Helen%20Jade/OneDrive/Desktop/2022-topic-01-team-04/versuch.ipynb#ch0000005?line=2'>3</a> # mit preprocessing und unterschiedlichen Filtern (Gaus vs Median) erneut Dice score
#    (...)
# ...
