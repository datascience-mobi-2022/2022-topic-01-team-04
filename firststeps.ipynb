# %%
# %pylab
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: QtAgg
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
img_1 = imread(r"data\Otsu_data\NIH3T3\gt\0.png") 
figure()  
imshow(img_1, 'gray')


img_2 = imread(r"data\Otsu_data\NIH3T3\img\dna-0.png") 
figure()    
imshow(img_2, 'gray')

# %%
#copy = img_2.copy()
#import scipy.ndimage
#median = scipy.ndimage.median_filter(copy, 5)
#figure()
#imshow(median, 'gray')
#colorbar()

# %%
#def histogramm (img):
 #   result = list()
#
 #   for p in ndindex(img.shape):
  #  
   #     result.append(img[p])
    #   
    #hist(result, bins = 50, density=True, 
     #                       edgecolor="#6A9662",
      #                      color="#DDFFDD")


#histogramm(img_1)
#histogramm(img_2)
#histogramm(copy)
#plt.xlim([0,50])
***

# %%
#histogramm(img_1)
#hist(img_1)
#hist(img_2)
# Out:
# (array([[682.,  61., 237., ...,   0.,   0.,   0.],
#         [679.,  63., 231., ...,   0.,   0.,   0.],
#         [677.,  62., 235., ...,   0.,   0.,   0.],
#         ...,
#         [928.,  14.,  19., ...,   0.,   0.,   0.],
#         [930.,  11.,  15., ...,   0.,   0.,   0.],
#         [927.,  14.,  12., ...,   0.,   0.,   0.]]),
#  array([0.07058824, 0.10078432, 0.1309804 , 0.16117647, 0.19137256,
#         0.22156863, 0.2517647 , 0.2819608 , 0.31215686, 0.34235296,
#         0.37254903], dtype=float32),
#  <a list of 1344 BarContainer objects>)
