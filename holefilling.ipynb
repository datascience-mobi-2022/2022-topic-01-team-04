# %%
# %pylab
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
# Out:
# Using matplotlib backend: <object object at 0x000001DC87792D80>
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
imgdnagt = imread (r"data\Otsu_data\NIH3T3\gt\44.png")
figure()
imshow(imgdna44gt, 'gray')
colorbar()

# %%
#bereits implimentierter hole filling code

closing = cv2.morphologyEx(imgdnagt , cv2.MORPH_CLOSE, ip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Helen Jade\OneDrive\Desktop\2022-topic-01-team-04\holefilling.ipynb Cell 3' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Helen%20Jade/OneDrive/Desktop/2022-topic-01-team-04/holefilling.ipynb#ch0000001?line=0'>1</a> #bereits implimentierter hole filling code
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Helen%20Jade/OneDrive/Desktop/2022-topic-01-team-04/holefilling.ipynb#ch0000001?line=2'>3</a> closing = cv2.morphologyEx(imgdnagt , cv2.MORPH_CLOSE, ipykernel)
#
# NameError: name 'ipykernel' is not defined
