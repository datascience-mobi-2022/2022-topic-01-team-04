# %%
# %pylab
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
# Out:
# Using matplotlib backend: QtAgg
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
imgdnagt = imread (r"data\Otsu_data\NIH3T3\gt\37.png")
figure()
imshow(imgdnagt, 'gray')
colorbar()

# %%
#bereits implimentierter hole filling code
#kernel festlegen
k1 = np.ones((3,3))
closing = cv2.morphologyEx(imgdnagt , cv2.MORPH_CLOSE, k1 )

# %%
imshow(closing, 'gray')
colorbar()
