# %%
# %pylab
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\ievas\Desktop\2022-topic-01-team-04\code\preprocessing.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ievas/Desktop/2022-topic-01-team-04/code/preprocessing.ipynb#ch0000000?line=0'>1</a> get_ipython().run_line_magic('pylab', '')
#       <a href='vscode-notebook-cell:/c%3A/Users/ievas/Desktop/2022-topic-01-team-04/code/preprocessing.ipynb#ch0000000?line=1'>2</a> get_ipython().run_line_magic('matplotlib', 'inline')
#       <a href='vscode-notebook-cell:/c%3A/Users/ievas/Desktop/2022-topic-01-team-04/code/preprocessing.ipynb#ch0000000?line=2'>3</a> import matplotlib.pyplot as plt
#
# File c:\Users\ievas\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:2304, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
# ...
